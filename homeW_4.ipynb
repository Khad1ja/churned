# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
data = pd.read_csv('Telco_Customer_Churn.csv')

# %%
data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
partner = pd.get_dummies(data['Partner'],prefix='partner',drop_first=True)
dependents = pd.get_dummies(data['Dependents'],prefix='Dependents',drop_first=True)
service = pd.get_dummies(data['PhoneService'],prefix='PhoneService',drop_first=True)
security = pd.get_dummies(data['OnlineSecurity'],prefix='OnlineSecurity',drop_first=True)
TechSupport = pd.get_dummies(data['TechSupport'],prefix='TechSupport',drop_first=True)
Contract = pd.get_dummies(data['Contract'],prefix='Contract',drop_first=True)
PaperlessBilling = pd.get_dummies(data['PaperlessBilling'],prefix='PaperlessBilling',drop_first=True)
Churn = pd.get_dummies(data['Churn'],prefix='Churn',drop_first=True)
gender = pd.get_dummies(data['gender'],prefix='gender',drop_first=True)
MultipleLines = pd.get_dummies(data['MultipleLines'],prefix='MultipleLines',drop_first=True)
Contract = pd.get_dummies(data['Contract'],prefix='Contract',drop_first=True)
PaymentMethod = pd.get_dummies(data['PaymentMethod'],prefix='PaymentMethod',drop_first=True)
InternetService = pd.get_dummies(data['InternetService'],prefix='InternetService',drop_first=True)
OnlineBackup = pd.get_dummies(data['OnlineBackup'],prefix='OnlineBackup',drop_first=True)

# %%
data.drop(['Partner','Dependents','PhoneService','OnlineSecurity','TechSupport','Contract','PaperlessBilling','Churn'],axis=1,inplace=True)

# %%
data
# Out:
#       gender  SeniorCitizen  tenure     MultipleLines InternetService  \
# 0     Female              0       1  No phone service             DSL
# 1       Male              0      34                No             DSL
# 2       Male              0       2                No             DSL
# 3       Male              0      45  No phone service             DSL
# 4     Female              0       2                No     Fiber optic
# ...      ...            ...     ...               ...             ...
# 7027    Male              0      24               Yes             DSL
# 7028  Female              0      72               Yes     Fiber optic
# 7029  Female              0      11  No phone service             DSL
# 7030    Male              1       4               Yes     Fiber optic
# 7031    Male              0      66                No     Fiber optic
#
#      OnlineBackup DeviceProtection StreamingTV StreamingMovies  \
# ...

# %%
data.drop(['MultipleLines','InternetService','OnlineBackup','DeviceProtection','StreamingTV','StreamingMovies','PaymentMethod'],axis=1,inplace=True)

# %%
data
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 0                 0       1           29.85         29.85
# 1                 0      34           56.95       1889.50
# 2                 0       2           53.85        108.15
# 3                 0      45           42.30       1840.75
# 4                 0       2           70.70        151.65
# ...             ...     ...             ...           ...
# 7027              0      24           84.80       1990.50
# 7028              0      72          103.20       7362.90
# 7029              0      11           29.60        346.45
# 7030              1       4           74.40        306.60
# 7031              0      66          105.65       6844.50
#
# [7032 rows x 4 columns]

# %%
data = pd.concat([data,partner,
dependents,
service,
security, 
TechSupport,
Contract,
PaperlessBilling,
Churn,
gender,
MultipleLines,
Contract,
PaymentMethod,InternetService,
OnlineBackup ],axis=1)

# %%
data
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  partner_Yes  \
# 0                 0       1           29.85         29.85            1
# 1                 0      34           56.95       1889.50            0
# 2                 0       2           53.85        108.15            0
# 3                 0      45           42.30       1840.75            0
# 4                 0       2           70.70        151.65            0
# ...             ...     ...             ...           ...          ...
# 7027              0      24           84.80       1990.50            1
# 7028              0      72          103.20       7362.90            1
# 7029              0      11           29.60        346.45            1
# 7030              1       4           74.40        306.60            1
# 7031              0      66          105.65       6844.50            0
#
#       Dependents_Yes  PhoneService_Yes  OnlineSecurity_No internet service  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
y = data['Churn_Yes']

# %%
X = data.drop('Churn_Yes',axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lm = LogisticRegression()
lm.fit(X_train,y_train)
predict = lm.predict(X_test)
# Out:
# C:\Users\Sadiq\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import classification_report

# %%
print('classification report LogisticRegression: \n', classification_report(y_test,predict))
# Out:
# classification report LogisticRegression:
#                precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88      1580
#            1       0.64      0.55      0.59       530
#
#     accuracy                           0.81      2110
#    macro avg       0.75      0.72      0.73      2110
# weighted avg       0.80      0.81      0.80      2110

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gb = GaussianNB()

# %%
gb.fit(X_train,y_train)
predict = gb.predict(X_test)

# %%
print('classification report Naive Bayes: \n', classification_report(y_test,predict))
# Out:
# classification report Naive Bayes:
#                precision    recall  f1-score   support
#
#            0       0.91      0.65      0.76      1580
#            1       0.44      0.80      0.57       530
#
#     accuracy                           0.69      2110
#    macro avg       0.67      0.73      0.66      2110
# weighted avg       0.79      0.69      0.71      2110

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dfc = DecisionTreeClassifier(criterion='gini')

# %%
dfc.fit(X_train,y_train)
predict = dfc.predict(X_test)

# %%
print('classification report Decision Tree: \n', classification_report(y_test,predict))
# Out:
# classification report Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.83      0.78      0.81      1580
#            1       0.45      0.53      0.49       530
#
#     accuracy                           0.72      2110
#    macro avg       0.64      0.66      0.65      2110
# weighted avg       0.74      0.72      0.73      2110

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
svc.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-200-ea6b1993093e> in <module>
# ----> 1 svc.fit(X_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     215
#     216         seed = rnd.randint(np.iinfo('i').max)
# --> 217         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     218         # see comment on the other call to np.iinfo in this file
#     219
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     266         self.support_, self.support_vectors_, self._n_support, \
#     267             self.dual_coef_, self.intercept_, self._probA, \
# --> 268             self._probB, self.fit_status_ = libsvm.fit(
#     269                 X, y,
# ...

# %%
svc = SVC(kernel='linear',random_state=101)

# %%
predict = svc.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-236-9fd1e2042109> in <module>
# ----> 1 predict = svc.predict(X_train)
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in predict(self, X)
#     603             Class labels for samples in X.
#     604         """
# --> 605         check_is_fitted(self)
#     606         if self.break_ties and self.decision_function_shape == 'ovo':
#     607             raise ValueError("break_ties must be False when "
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ...

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(random_state=101)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=101)

# %%
predict = rfc.predict(X_test)

# %%
print('classification report Random Forest: \n', classification_report(y_test,predict))
# Out:
# classification report Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1580
#            1       0.60      0.48      0.54       530
#
#     accuracy                           0.79      2110
#    macro avg       0.72      0.69      0.70      2110
# weighted avg       0.78      0.79      0.78      2110

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
nn = KNeighborsClassifier(n_neighbors=10)

# %%
nn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
predict = nn.predict(X_test)

# %%
print('classification report KNeighborsClassifier: \n', classification_report(y_test,predict))
# Out:
# classification report KNeighborsClassifier:
#                precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87      1580
#            1       0.62      0.37      0.46       530
#
#     accuracy                           0.79      2110
#    macro avg       0.72      0.65      0.67      2110
# weighted avg       0.77      0.79      0.77      2110

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

class_model = []

class_model.append(("Logistic Regression", LogisticRegression(solver='liblinear')))
class_model.append(("GaussianNB", GaussianNB()))
class_model.append(("DecisionTreeClassifier", DecisionTreeClassifier(criterion='gini')))
class_model.append(("RandomForestClassifier", RandomForestClassifier(n_estimators=100,criterion='gini')))
class_model.append(("KNeighborsClassifier", KNeighborsClassifier(n_neighbors=10)))

for name, model in class_model:
    kfold = KFold(n_splits=10,random_state=None)
    result = cross_val_score(model, X, y, cv=kfold, scoring='accuracy')
    print(result.mean())
# Out:
# 0.8033272581792319
# 0.6980925901978534
# 0.7218422669080564
# 0.7918080386008018
# 0.7825657894736842
